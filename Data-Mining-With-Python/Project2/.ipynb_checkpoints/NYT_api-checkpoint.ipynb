# %%
import http.client, urllib.parse

conn = http.client.HTTPSConnection("api.nytimes.com")

headers = urllib.parse.urlencode({
    'api-key': 'a6G55wI3dTomud2zjcVQGDgreT5ARPBA'
    })

conn.request("GET", "/svc/news/v3/content/all/all.json?{}".format(headers))

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"status":"OK","copyright":"Copyright (c) 2021 The New York Times Company.  All Rights Reserved.","num_results":500,"results":[{"slug_name":"10wuhan-rebrand","section":"World","subsection":"Asia Pacific","title":"A Year After Wuhan, China Tells a Tale of Triumph (and No Mistakes)","abstract":"The Chinese Communist Party’s efforts to hide its missteps have taken on new urgency as the anniversary of the world’s first Covid-19 lockdown nears.","url":"https://www.nytimes.com/2021/01/10/world/asia/wuhan-china-coronavirus.html","byline":"BY AMY QIN AND JAVIER C. HERNÁNDEZ","thumbnail_standard":"https://static01.nyt.com/images/2021/01/09/world/09wuhan-rebrand-top/09wuhan-rebrand-top-thumbStandard.jpg","item_type":"Article","source":"New York Times","updated_date":"2021-01-10T12:26:43-05:00","created_date":"2021-01-10T12:26:43-05:00","published_date":"2021-01-10T12:26:43-05:00","first_published_date":"2021-01-10T12:26:43-05:00","material_type_facet":"News","kicker":"","subheadline":"","des_f
# ...
