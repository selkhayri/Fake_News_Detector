# %%
import http.client, urllib.parse

conn = http.client.HTTPConnection('newsapi.org')

params = urllib.parse.urlencode({
    'apiKey': 'ba61eeb0dda74bc7836c7bf946cf74f8',
    'from': '2020-12-10',
    'sortBy': 'publishedAt',
    'q': 'real fake news',
    })

conn.request('GET', '/v2/everything?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"status":"ok","totalResults":2032,"articles":[{"source":{"id":null,"name":"POLITICO.eu"},"author":"Thierry Breton","title":"Thierry Breton: Capitol Hill — the 9/11 moment of social media","description":"The Capitol Hill riot exposes the fragility of our democracies — and the threat underregulated tech companies can pose to their survival.","url":"http://www.politico.eu/article/thierry-breton-social-media-capitol-hill-riot/","urlToImage":"https://www.politico.eu/wp-content/uploads/2021/01/10/GettyImages-1230455457-1200x628.jpg","publishedAt":"2021-01-10T15:50:05Z","content":"Thierry Breton is European commissioner for the internal market.\r\nWe are all still shocked by the images of protesters storming the U.S. Congress to halt the certification of the next U.S. president.… [+4500 chars]"},{"source":{"id":null,"name":"The Daily Wire"},"author":"Hank Berrien","title":"‘Most Important Moment In The History Of Social Media’: Sacha Baron Cohen Praises Twitter, Facebook For Banning Trump"
# ...
